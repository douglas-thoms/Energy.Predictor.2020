# %% [markdown]
# # Overview
#
# - this is a baseline model to determine immediate performance
# - will use gradient boost modelling using package XGboost
# - no data cleaning feature engineering to be used

# %%
# General Imports

import numpy as np
import pandas as pd
import pickle

import os, gc, sys, warnings, random, psycopg2

# %%
# Functions

def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)

# %%
SEED = 42
LOCAL_TEST = False
seed_everything(SEED)
TARGET = 'meter_reading'

# %%
# open pickle files

train_df = pd.read_pickle('train_df.pkl')
test_df = pd.read_pickle('test_df.pkl')
submission = pd.read_pickle('submission.pkl')

# %%
#data check#data check
print("Main:",list(train_df),train_df.info())
print("#" * 20)
print("Main:",list(test_df),test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216100 entries, 0 to 20216099
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   building_id         int16
#  1   site_id             int8
#  2   meter               int8
#  3   meter_reading       float64
#  4   timestamp           datetime64[ns]
#  5   primary_use         int8
#  6   square_feet         int32
#  7   year_built          int8
#  8   floor_count         int8
#  9   air_temperature     float64
#  10  cloud_coverage      float16
#  11  dew_temperature     float64
#  12  precip_depth_1_hr   float16
#  13  sea_level_pressure  float64
#  14  wind_direction      float16
#  15  wind_speed          float64
#  16  DT_month            int8
#  17  DT_week_y           int8
#  18  DT_day_y            int8
#  19  DT_hour             int8
#  20  DT_day_w            int8
#  21  DT_day_m            int8
#  22  DT_week_m           int8
# dtypes: datetime64[ns](1), float16(3), float64(5), int16(1), int32(1), int8(12)
# memory usage: 1.4 GB
# Main: ['building_id', 'site_id', 'meter', 'meter_reading', 'timestamp', 'primary_use', 'square_feet', 'year_built', 'floor_count', 'air_temperature', 'cloud_coverage', 'dew_temperature', 'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed', 'DT_month', 'DT_week_y', 'DT_day_y', 'DT_hour', 'DT_day_w', 'DT_day_m', 'DT_week_m'] None
# ####################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41697600 entries, 0 to 41697599
# Data columns (total 23 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   row_id              int32
#  1   building_id         int16
#  2   site_id             int8
#  3   meter               int8
#  4   timestamp           datetime64[ns]
#  5   primary_use         int8
#  6   square_feet         int32
#  7   year_built          int8
#  8   floor_count         int8
#  9   air_temperature     float64
#  10  cloud_coverage      float16
#  11  dew_temperature     float64
#  12  precip_depth_1_hr   float16
#  13  sea_level_pressure  float64
#  14  wind_direction      float16
#  15  wind_speed          float64
#  16  DT_month            int8
#  17  DT_week_y           int8
#  18  DT_day_y            int8
#  19  DT_hour             int8
#  20  DT_day_w            int8
#  21  DT_day_m            int8
#  22  DT_week_m           int8
# dtypes: datetime64[ns](1), float16(3), float64(4), int16(1), int32(2), int8(12)
# memory usage: 2.6 GB
# Main: ['row_id', 'building_id', 'site_id', 'meter', 'timestamp', 'primary_use', 'square_feet', 'year_built', 'floor_count', 'air_temperature', 'cloud_coverage', 'dew_temperature', 'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed', 'DT_month', 'DT_week_y', 'DT_day_y', 'DT_hour', 'DT_day_w', 'DT_day_m', 'DT_week_m'] None

# %%
# Check memory usage

# %%
#prepare training data
import xgboost as xgb

#choose columns to remove
remove_columns = [TARGET,'timestamp']
#get feature columns using list comprehension to remove columns - list(train_df)
feature_columns = [col for col in list(train_df) if col not in remove_columns]

#label is target

tr_data = xgb.DMatrix(train_df[feature_columns],label=train_df[TARGET])

# %%
# Model Parameters


xgb_param = {'max_depth': 2, 
         'eta': 1, 
         'objective': 'reg:squaredlogerror',

#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  47.608982,
#  47.608982,
#  47.608982,
#  31.279543,
#  80.18934,
#  80.18934,
#  80.18934,
#  36.146908,
#  36.146908,
#  36.146908,
#  36.146908,
#  36.146908,
#  36.146908,
#  80.18934,
#  80.18934,
#  80.18934,
#  80.18934,
#  69.945656,
#  69.945656,
#  69.945656,
#  80.18934,
#  36.146908,
#  36.146908,
#  80.18934,
#  80.18934,
#  80.18934,
#  36.146908,
#  80.18934,
#  80.18934,
#  80.18934,
#  47.608982,
#  47.608982,
#  47.542156,
#  47.542156,
#  47.542156,
#  36.146908,
#  36.146908,
#  36.146908,
#  80.18934,
#  80.18934,
#  80.18934,
#  69.945656,
#  69.945656,
#  69.945656,
#  36.146908,
#  36.146908,
#  36.146908,
#  47.608982,
#  47.608982,
#  47.608982,
#  36.146908,
#  36.146908,
#  36.146908,
#  68.91796,
#  68.91796,
#  68.91796,
#  58.67428,
#  58.67428,
#  58.67428,
#  58.67428,
#  15.856184,
#  15.856184,
#  68.91796,
#  36.337605,
#  36.337605,
#  36.337605,
#  36.337605,
#  24.87553,
#  24.87553,
#  24.87553,
#  36.337605,
#  36.337605,
#  24.87553,
#  24.87553,
#  20.684088,
#  36.337605,
#  36.337605,
#  24.87553,
#  24.87553,
#  36.337605,
#  36.337605,
#  24.87553,
#  15.856184,
#  15.856184,
#  20.513271,
#  58.67428,
#  58.67428,
#  58.67428,
#  68.91796,
#  68.91796,
#  24.87553,
#  76.22845,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  110.808624,
#  110.808624,
#  110.808624,
#  119.8936,
#  119.8936,
#  42.429695,
#  76.22845,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  53.89177,
#  53.89177,
#  42.429695,
#  42.429695,
#  42.429695,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  76.22845,
#  76.22845,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  42.429695,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  76.22845,
#  76.22845,
#  76.22845,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  42.429695,
#  42.429695,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  53.89177,
#  53.89177,
#  42.429695,
#  42.429695,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  53.89177,
#  42.429695,
#  42.429695,
#  42.429695,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  119.8936,
#  53.89177,
#  53.824944,
#  53.824944,
#  53.89177,
#  53.89177,
#  38.238255,
#  42.429695,
#  42.429695,
#  53.89177,
#  117.23033,
#  117.23033,
#  117.23033,
#  42.429695,
#  42.429695,
#  110.808624,
#  110.808624,
#  117.23033,
#  117.23033,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  53.89177,
#  53.89177,
#  76.22845,
#  76.22845,
#  76.22845,
#  119.8936,
#  119.8936,
#  76.22845,
#  76.22845,
#  42.429695,
#  53.89177,
#  53.89177,
#  53.89177,
#  42.429695,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  76.22845,
#  76.22845,
#  42.429695,
#  42.429695,
#  53.824944,
#  53.824944,
#  42.429695,
#  42.429695,
#  53.89177,
#  53.89177,
#  38.238255,
#  119.8936,
#  119.8936,
#  53.89177,
#  53.89177,
#  42.429695,
#  42.429695,
#  117.23033,
#  117.23033,
#  42.429695,
#  119.8936,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  76.22845,
#  76.22845,
#  76.22845,
#  76.22845,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  119.8936,
#  119.8936,
#  119.8936,
#  53.89177,
#  38.238255,
#  38.238255,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  53.89177,
#  53.89177,
#  53.89177,
#  119.8936,
#  119.8936,
#  119.8936,
#  42.429695,
#  119.8936,
#  63.81746,
#  63.81746,
#  63.81746,
#  38.606205,
#  38.606205,
#  38.606205,
#  97.61621,
#  97.61621,
#  97.61621,
#  38.606205,
#  38.606205,
#  38.606205,
#  75.27953,
#  75.27953,
#  75.27953,
#  141.28137,
#  141.28137,
#  141.28137,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  34.414764,
#  34.414764,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  141.28137,
#  141.28137,
#  141.28137,
#  75.27953,
#  75.27953,
#  75.27953,
#  38.606205,
#  38.606205,
#  38.606205,
#  97.61621,
#  97.61621,
#  97.61621,
#  38.606205,
#  38.606205,
#  75.27953,
#  75.27953,
#  75.27953,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  38.606205,
#  38.606205,
#  38.606205,
#  141.28137,
#  141.28137,
#  141.28137,
#  75.27953,
#  75.27953,
#  75.27953,
#  38.606205,
#  38.606205,
#  38.606205,
#  63.81746,
#  63.81746,
#  63.81746,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  97.61621,
#  97.61621,
#  97.61621,
#  97.61621,
#  97.61621,
#  97.61621,
#  138.10526,
#  138.10526,
#  138.10526,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  75.27953,
#  141.28137,
#  141.28137,
#  141.28137,
#  141.28137,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  38.606205,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  75.27953,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  34.414764,
#  34.414764,
#  34.414764,
#  138.6181,
#  138.6181,
#  138.6181,
#  38.606205,
#  38.606205,
#  38.606205,
#  75.21271,
#  75.21271,
#  75.21271,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  38.606205,
#  141.28137,
#  141.28137,
#  141.28137,
#  97.61621,
#  97.61621,
#  97.61621,
#  38.606205,
#  38.606205,
#  38.606205,
#  97.61621,
#  97.61621,
#  97.61621,
#  72.65729,
#  72.65729,
#  72.65729,
#  38.606205,
#  75.27953,
#  75.27953,
#  75.27953,
#  ...]

# %%
train_df.head()
# Out:
#    building_id  site_id  meter  meter_reading  timestamp  primary_use  \
# 0          222        2      1        11.1132 2016-01-01            1
# 1            0        0      0         0.0000 2016-01-01            0
# 2            1        0      0         0.0000 2016-01-01            0
# 3            2        0      0         0.0000 2016-01-01            0
# 4            3        0      0         0.0000 2016-01-01            0
#
#    square_feet  year_built  floor_count  air_temperature  ...  \
# 0        11935        -109            0             15.6  ...
# 1         7432         -40            0             25.0  ...
# 2         2720         -44            0             25.0  ...
# 3         5376         -57            0             25.0  ...
# 4        23685         -46            0             25.0  ...
#
#    sea_level_pressure  wind_direction  wind_speed  DT_month  DT_week_y  \
# 0              1015.3           270.0         3.6         1         53
# 1              1019.7             0.0         0.0         1         53
# 2              1019.7             0.0         0.0         1         53
# 3              1019.7             0.0         0.0         1         53
# 4              1019.7             0.0         0.0         1         53
#
#    DT_day_y  DT_hour  DT_day_w  DT_day_m  DT_week_m
# 0         1        0         4         1          1
# 1         1        0         4         1          1
# 2         1        0         4         1          1
# 3         1        0         4         1          1
# 4         1        0         4         1          1
#
# [5 rows x 23 columns]

# %%
# plot the two against each other

#bring two dataframes together

print(len(predictions))
# Out:
# 20216100

# %%
print(train_df.shape[0])
# Out:
# 20216100

# %%
pd.concat(train_df,predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-f6464df9ecc8> in <module>
# ----> 1 pd.concat(train_df,predictions)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     318     ):
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 320             raise TypeError(
#     321                 "first argument must be an iterable of pandas "
#     322                 f'objects, you passed an object of type "{type(objs).__name__}"'
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %% [markdown]
# https://www.kaggle.com/volker48/xgboost-custom-rmsle-eval-function

# %%
xgb.cv(xgb_param,tr_data,num_boost_round=10,nfold=5,verbose_eval=True)
